# %% [markdown]
# # PET328 2024/2025

# %% [markdown]
# ## Class Demonstration

# %% [markdown]
# Hello PET328 Assembly

# %%
3+4
# Out:
# 7

# %%
radius = 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The formula for computing area of a triangle is given as $A = \frac{1}{2}bh$
